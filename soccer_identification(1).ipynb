# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 14.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 41.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 28.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 41.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 87.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="kjnlY4fSrQO8TCQ2ENqB")
project = rf.workspace("pranali-5cqjv").project("soccerplayeridentification")
version = project.version(4)
dataset = version.download("yolov11")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.7/86.7 kB 3.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 4.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 20.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 105.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.11.0.86
#     Uninstalling opencv-python-headless-4.11.0.86:
#       Successfully uninstalled opencv-python-headless-4.11.0.86
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to soccerplayeridentification-4 in yolov11:: 100%|██████████| 66/66 [00:00<00:00, 5410.31it/s]

# %%
from ultralytics import YOLO

# Load a pretrained YOLO11n model
model = YOLO("yolo11n.pt")

# Train the model on the COCO8 dataset for 100 epochs
train_results = model.train(
    data="/content/soccerplayeridentification-4/data.yaml",  # Path to dataset configuration file
    epochs=100,  # Number of training epochs
    imgsz=640,  # Image size for training
    device="cpu",  # Device to run on (e.g., 'cpu', 0, [0,1,2,3])
)

# Evaluate the model's performance on the validation set
metrics = model.val()

# Perform object detection on an image
results = model("/content/soccerplayeridentification-4/train/images/broadcast_mp4-0003_jpg.rf.eb868ca53657e5cedb354e82e44dc948.jpg")  # Predict on an image
results[0].show()  # Display results

# Export the model to ONNX format for deployment
# Out:
# Ultralytics 8.3.154 🚀 Python-3.11.13 torch-2.6.0+cu124 CPU (Intel Xeon 2.20GHz)
# ...

# %%
path = model.export(format="onnx")  # Returns the path to the exported model
# Out:
# Ultralytics 8.3.154 🚀 Python-3.11.13 torch-2.6.0+cu124 CPU (Intel Xeon 2.20GHz)
#
# PyTorch: starting from 'runs/detect/train3/weights/best.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 6, 8400) (5.2 MB)
#
# ONNX: starting export with onnx 1.17.0 opset 19...
# ONNX: slimming with onnxslim 0.1.57...
# ONNX: export success ✅ 2.2s, saved as 'runs/detect/train3/weights/best.onnx' (10.1 MB)
#
# Export complete (2.7s)
# Results saved to /content/runs/detect/train3/weights
# Predict:         yolo predict task=detect model=runs/detect/train3/weights/best.onnx imgsz=640
# Validate:        yolo val task=detect model=runs/detect/train3/weights/best.onnx imgsz=640 data=/content/soccerplayeridentification-4/data.yaml
# Visualize:       https://netron.app

# %%
pred = model.predict(source="/content/soccerplayeridentification-4/train/images/broadcast_mp4-0003_jpg.rf.eb868ca53657e5cedb354e82e44dc948.jpg", save=True)
# Out:
# image 1/1 /content/soccerplayeridentification-4/train/images/broadcast_mp4-0003_jpg.rf.eb868ca53657e5cedb354e82e44dc948.jpg: 640x640 9 players, 259.4ms
# Speed: 6.6ms preprocess, 259.4ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/train33

# %%
pred
# Out:
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'football', 1: 'player'}
#  obb: None
#  orig_img: array([[[  6,   6,   6],
#          [  9,   9,   9],
#          [ 12,  12,  12],
#          ...,
#          [ 24,  24,  24],
#          [ 14,  14,  14],
#          [  3,   3,   3]],
#
#         [[  7,   7,   7],
#          [  7,   7,   7],
#          [  9,   9,   9],
#          ...,
#          [ 33,  33,  33],
#          [ 28,  28,  28],
#          [ 19,  19,  19]],
#
#         [[  9,   9,   9],
#          [  5,   5,   5],
#          [  6,   6,   6],
#          ...,
#          [ 54,  54,  54],
#          [ 46,  46,  46],
#          [ 33,  33,  33]],
#
#         ...,
#
#         [[104, 104, 104],
#          [104, 104, 104],
#          [103, 103, 103],
#          ...,
#          [134, 134, 134],
#          [134, 134, 134],
#          [134, 134, 134]],
#
# ...

# %%
# show prediction image

pred[0].plot()
# Out:
# array([[[  6,   6,   6],
#         [  9,   9,   9],
#         [ 12,  12,  12],
#         ...,
#         [ 24,  24,  24],
#         [ 14,  14,  14],
#         [  3,   3,   3]],
#
#        [[  7,   7,   7],
#         [  7,   7,   7],
#         [  9,   9,   9],
#         ...,
#         [ 33,  33,  33],
#         [ 28,  28,  28],
#         [ 19,  19,  19]],
#
#        [[  9,   9,   9],
#         [  5,   5,   5],
#         [  6,   6,   6],
#         ...,
#         [ 54,  54,  54],
#         [ 46,  46,  46],
#         [ 33,  33,  33]],
#
#        ...,
#
#        [[104, 104, 104],
#         [104, 104, 104],
#         [103, 103, 103],
#         ...,
#         [134, 134, 134],
#         [134, 134, 134],
#         [134, 134, 134]],
#
#        [[103, 103, 103],
#         [103, 103, 103],
#         [103, 103, 103],
#         ...,
#         [134, 134, 134],
#         [134, 134, 134],
#         [134, 134, 134]],
#
#        [[103, 103, 103],
#         [103, 103, 103],
#         [103, 103, 103],
# ...
